# %%
# !python -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==4.8.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: asttokens==3.0.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.4 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: attrs==25.1.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: babel==2.17.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (2.17.0)
# Requirement already satisfied: beautifulsoup4==4.13.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (4.13.3)
# Requirement already satisfied: bleach==6.2.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (6.2.0)
# Requirement already satisfied: certifi==2025.1.31 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (2025.1.31)
# Requirement already satisfied: cffi==1.17.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: comm==0.2.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: cycler==0.12.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.13 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (1.8.13)
# Requirement already satisfied: decorator==5.2.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (5.2.1)
# Requirement already satisfied: defusedxml==0.7.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: executing==2.2.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (2.2.0)
# Requirement already satisfied: fastjsonschema==2.21.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (2.21.1)
# Requirement already satisfied: fonttools==4.56.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (4.56.0)
# Requirement already satisfied: fqdn==1.5.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (1.5.1)
# Requirement already satisfied: h11==0.14.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.7 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (1.0.7)
# Requirement already satisfied: httpx==0.28.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (0.28.1)
# Requirement already satisfied: idna==3.10 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (6.29.5)
# Requirement already satisfied: ipython==9.0.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (9.0.1)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (1.1.1)
# Requirement already satisfied: ipywidgets==8.1.5 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (8.1.5)
# Requirement already satisfied: isoduration==20.11.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 33)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 34)) (3.1.6)
# Requirement already satisfied: json5==0.10.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 35)) (0.10.0)
# Requirement already satisfied: jsonpointer==3.0.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 36)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 37)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2024.10.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 38)) (2024.10.1)
# Requirement already satisfied: jupyter==1.1.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 39)) (1.1.1)
# Requirement already satisfied: jupyter-console==6.6.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 40)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.12.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 41)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 42)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 43)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 44)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.15.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 45)) (2.15.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 46)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.3.5 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 47)) (4.3.5)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 48)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 49)) (2.27.3)
# Requirement already satisfied: jupyterlab_widgets==3.0.13 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 50)) (3.0.13)
# Requirement already satisfied: kiwisolver==1.4.8 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 51)) (1.4.8)
# Requirement already satisfied: MarkupSafe==3.0.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 52)) (3.0.2)
# Requirement already satisfied: matplotlib==3.10.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 53)) (3.10.1)
# Requirement already satisfied: matplotlib-inline==0.1.7 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 54)) (0.1.7)
# Requirement already satisfied: mistune==3.1.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 55)) (3.1.2)
# Requirement already satisfied: nbclient==0.10.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 56)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 57)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 58)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 59)) (1.6.0)
# Requirement already satisfied: notebook==7.3.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 60)) (7.3.2)
# Requirement already satisfied: notebook_shim==0.2.4 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 61)) (0.2.4)
# Requirement already satisfied: numpy==2.2.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 62)) (2.2.3)
# Requirement already satisfied: overrides==7.7.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 63)) (7.7.0)
# Requirement already satisfied: packaging==24.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 64)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 65)) (2.2.3)
# Requirement already satisfied: pandocfilters==1.5.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 66)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 67)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 68)) (4.9.0)
# Requirement already satisfied: pillow==11.1.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 69)) (11.1.0)
# Requirement already satisfied: platformdirs==4.3.6 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 70)) (4.3.6)
# Requirement already satisfied: prometheus_client==0.21.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 71)) (0.21.1)
# Requirement already satisfied: prompt_toolkit==3.0.50 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 72)) (3.0.50)
# Requirement already satisfied: psutil==7.0.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 73)) (7.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 74)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 75)) (0.2.3)
# Requirement already satisfied: pycparser==2.22 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 76)) (2.22)
# Requirement already satisfied: Pygments==2.19.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 77)) (2.19.1)
# Requirement already satisfied: pyparsing==3.2.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 78)) (3.2.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 79)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==3.3.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 80)) (3.3.0)
# Requirement already satisfied: pytz==2025.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 81)) (2025.1)
# Requirement already satisfied: PyYAML==6.0.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 82)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 83)) (26.2.1)
# Requirement already satisfied: referencing==0.36.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 84)) (0.36.2)
# Requirement already satisfied: requests==2.32.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 85)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 86)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 87)) (0.1.1)
# Requirement already satisfied: rpds-py==0.23.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 88)) (0.23.1)
# Requirement already satisfied: scipy==1.15.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 89)) (1.15.2)
# Requirement already satisfied: seaborn==0.13.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 90)) (0.13.2)
# Requirement already satisfied: Send2Trash==1.8.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 91)) (1.8.3)
# Requirement already satisfied: setuptools==75.8.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 92)) (75.8.2)
# Requirement already satisfied: six==1.17.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 93)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 94)) (1.3.1)
# Requirement already satisfied: soupsieve==2.6 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 95)) (2.6)
# Requirement already satisfied: stack-data==0.6.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 96)) (0.6.3)
# Requirement already satisfied: terminado==0.18.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 97)) (0.18.1)
# Requirement already satisfied: tinycss2==1.4.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 98)) (1.4.0)
# Requirement already satisfied: tornado==6.4.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 99)) (6.4.2)
# Requirement already satisfied: traitlets==5.14.3 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 100)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20241206 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 101)) (2.9.0.20241206)
# Requirement already satisfied: typing_extensions==4.12.2 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 102)) (4.12.2)
# Requirement already satisfied: tzdata==2025.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 103)) (2025.1)
# Requirement already satisfied: uri-template==1.3.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 104)) (1.3.0)
# Requirement already satisfied: urllib3==2.3.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 105)) (2.3.0)
# Requirement already satisfied: wcwidth==0.2.13 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 106)) (0.2.13)
# Requirement already satisfied: webcolors==24.11.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 107)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 108)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 109)) (1.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.13 in ./comoveis/lib/python3.12/site-packages (from -r requirements.txt (line 110)) (4.0.13)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import mode

# %%
file_bts = "Bts.csv"
file_meds_train = "meds_train_alunos.csv"
file_submit = "submit_alunos.csv"
file_meds_test = "meds_test_alunos.csv"

# %%
df_bts = pd.read_csv(file_bts)
df_meds_train = pd.read_csv(file_meds_train)
df_submit = pd.read_csv(file_submit)
df_meds_test = pd.read_csv(file_meds_test)

# %%
datasets = {
    "df_bts": df_bts,
    "df_meds_train": df_meds_train,
    "df_submit": df_submit,
    "df_meds_test": df_meds_test
}

# %%
for name, dataset in datasets.items():
    print(name)
    print(dataset.dtypes)  # Exibe os tipos das colunas
    print("\n")
# Out:
# df_bts
# grupo           int64
# btsId          object
# btsNetNome     object
# lat           float64
# lon           float64
# cch             int64
# azimuth         int64
# RssiId         object
# dtype: object
#
#
# df_meds_train
# ponto_id      int64
# rssi_1_1    float64
# rssi_1_2    float64
# rssi_1_3    float64
# rssi_2_1    float64
# rssi_2_2    float64
# rssi_2_3    float64
# rssi_3_1    float64
# rssi_3_2    float64
# rssi_3_3    float64
# delay_1     float64
# delay_2     float64
# delay_3     float64
# lat         float64
# lon         float64
# indoor         bool
# dtype: object
#
#
# df_submit
# ponto_id      int64
# lat_pred    float64
# lon_pred    float64
# dtype: object
#
#
# df_meds_test
# ponto_id      int64
# rssi_1_1    float64
# rssi_1_2    float64
# rssi_1_3    float64
# rssi_2_1    float64
# rssi_2_2    float64
# rssi_2_3    float64
# rssi_3_1    float64
# rssi_3_2    float64
# rssi_3_3    float64
# delay_1     float64
# delay_2     float64
# delay_3     float64
# dtype: object

# %%
for name, dataset in datasets.items():
    print(name)
    print(dataset.shape) # Exibe o tamanho do dataset
    print(dataset.head())  # Exibe as primeiras linhas do dataset
    print("\n")
# Out:
# df_bts
# (9, 8)
#    grupo    btsId btsNetNome      lat        lon  cch  azimuth    RssiId
# 0      1  BTS_1_1  PEMDL01_1 -8.04342 -34.952000  873        0  rssi_1_1
# 1      1  BTS_1_2  PEMDL01_2 -8.04342 -34.952000  872      120  rssi_1_2
# 2      1  BTS_1_3  PEMDL01_3 -8.04342 -34.952000  875      240  rssi_1_3
# 3      2  BTS_2_1  PEMDL08_1 -8.05289 -34.944672  865        0  rssi_2_1
# 4      2  BTS_2_2  PEMDL08_2 -8.05289 -34.944672  874      120  rssi_2_2
#
#
# df_meds_train
# (6775, 16)
#    ponto_id    rssi_1_1    rssi_1_2    rssi_1_3    rssi_2_1    rssi_2_2  \
# 0      6604 -103.705000 -110.425000 -107.381667 -110.330000 -108.345000
# 1      5515 -105.225000 -115.000000 -105.210000 -115.000000 -105.835000
# 2      5049 -102.610000 -115.000000 -101.380000 -115.000000 -104.295000
# 3      8737  -89.140000  -97.251429  -86.642857  -96.036667  -96.592500
# 4      1203 -109.088333 -107.200000 -107.010000 -108.430000 -104.845714
#
#      rssi_2_3    rssi_3_1    rssi_3_2  rssi_3_3  delay_1  delay_2  delay_3  \
# 0 -106.590000 -107.153333 -102.120000   -115.00      5.0      3.0      2.0
# 1 -115.000000  -88.470000  -94.024286   -108.12      5.0      3.0      2.0
# 2  -97.360000  -96.980000  -99.572500   -115.00      5.0      3.0      2.0
# 3  -92.460000  -86.813333 -102.688000    -87.27      4.0      7.0      2.0
# 4 -101.435714 -103.065000 -102.110000   -115.00      5.0      3.0      2.0
#
#         lat        lon  indoor
# 0 -8.055786 -34.951505    True
# 1 -8.055784 -34.951608    True
# 2 -8.055506 -34.951693    True
# 3 -8.050390 -34.959630   False
# 4 -8.055380 -34.951736    True
#
#
# df_submit
# (2904, 3)
#    ponto_id  lat_pred  lon_pred
# 0         0      -8.0     -34.0
# 1         3      -8.0     -34.0
# 2         8      -8.0     -34.0
# 3        10      -8.0     -34.0
# 4        12      -8.0     -34.0
#
#
# df_meds_test
# (2904, 13)
#    ponto_id  rssi_1_1  rssi_1_2  rssi_1_3  rssi_2_1  rssi_2_2  rssi_2_3  \
# 0         0    -115.0    -115.0    -115.0    -115.0    -115.0    -115.0
# 1         3    -115.0    -115.0    -115.0    -115.0    -115.0    -115.0
# 2         8    -115.0    -115.0    -115.0    -115.0    -115.0    -115.0
# 3        10    -115.0    -115.0    -115.0    -115.0    -115.0    -115.0
# 4        12    -115.0    -115.0    -115.0    -115.0    -115.0    -115.0
#
#    rssi_3_1   rssi_3_2  rssi_3_3  delay_1  delay_2  delay_3
# 0    -90.93 -84.113333    -115.0      5.0      3.0      2.0
# 1    -90.93 -84.113333    -115.0      5.0      3.0      2.0
# 2    -90.93 -86.090000    -115.0      5.0      3.0      2.0
# 3    -90.93 -84.113333    -115.0      5.0      3.0      2.0
# 4    -90.93 -84.113333    -115.0      5.0      3.0      2.0

# %%
for name, dataset in datasets.items():
    print(name)
    print(dataset.isnull().sum())  # Exibe se existe valor nulo no dataset
    print("\n")
# Out:
# df_bts
# grupo         0
# btsId         0
# btsNetNome    0
# lat           0
# lon           0
# cch           0
# azimuth       0
# RssiId        0
# dtype: int64
#
#
# df_meds_train
# ponto_id    0
# rssi_1_1    0
# rssi_1_2    0
# rssi_1_3    0
# rssi_2_1    0
# rssi_2_2    0
# rssi_2_3    0
# rssi_3_1    0
# rssi_3_2    0
# rssi_3_3    0
# delay_1     0
# delay_2     0
# delay_3     0
# lat         0
# lon         0
# indoor      0
# dtype: int64
#
#
# df_submit
# ponto_id    0
# lat_pred    0
# lon_pred    0
# dtype: int64
#
#
# df_meds_test
# ponto_id    0
# rssi_1_1    0
# rssi_1_2    0
# rssi_1_3    0
# rssi_2_1    0
# rssi_2_2    0
# rssi_2_3    0
# rssi_3_1    0
# rssi_3_2    0
# rssi_3_3    0
# delay_1     0
# delay_2     0
# delay_3     0
# dtype: int64

# %%
# Análise de estatísticas descritivas
for name, df in datasets.items():
    print(f"Estatísticas de {name}:")
    print(df.describe(), "\n")
# Out:
# Estatísticas de df_bts:
#           grupo       lat        lon         cch     azimuth
# count  9.000000  9.000000   9.000000    9.000000    9.000000
# mean   2.000000 -8.050543 -34.951524  873.000000  120.000000
# std    0.866025  0.005445   0.005739    4.609772  103.923048
# min    1.000000 -8.055320 -34.957900  865.000000    0.000000
# 25%    1.000000 -8.055320 -34.957900  871.000000    0.000000
# 50%    2.000000 -8.052890 -34.952000  873.000000  120.000000
# 75%    3.000000 -8.043420 -34.944672  875.000000  240.000000
# max    3.000000 -8.043420 -34.944672  881.000000  240.000000
#
# Estatísticas de df_meds_train:
#           ponto_id     rssi_1_1     rssi_1_2     rssi_1_3     rssi_2_1  \
# count  6775.000000  6775.000000  6775.000000  6775.000000  6775.000000
# mean   4856.099779  -100.789923  -105.688802  -100.545198  -103.524786
# std    2785.645694    10.025728    10.397924     9.968138    13.367328
# min       1.000000  -115.000000  -115.000000  -115.000000  -115.000000
# 25%    2434.500000  -107.650000  -115.000000  -107.148571  -115.000000
# 50%    4875.000000  -103.040000  -110.425000   -99.750000  -108.430000
# 75%    7272.500000   -93.455000   -97.350000   -93.340000   -96.817917
# max    9676.000000   -61.380000   -64.820000   -60.640000   -36.960000
#
#           rssi_2_2     rssi_2_3     rssi_3_1     rssi_3_2     rssi_3_3  \
# count  6775.000000  6775.000000  6775.000000  6775.000000  6775.000000
# mean    -97.210290   -97.193499   -93.644749   -93.353728  -107.478361
# std       8.853480     9.992950     7.688089     8.110877    11.003407
# min    -115.000000  -115.000000  -113.140000  -115.630000  -115.000000
# 25%    -102.202857  -101.652857   -99.480000   -99.005000  -115.000000
# 50%     -97.170000   -95.615714   -94.785000   -95.688000  -115.000000
# 75%     -92.080000   -91.951429   -89.375000   -89.610500   -97.600000
# max     -59.170000   -56.980000   -56.060000   -55.870000   -52.540000
#
#            delay_1      delay_2      delay_3          lat          lon
# count  6775.000000  6775.000000  6775.000000  6775.000000  6775.000000
# mean      4.679410     3.159262     2.504945    -8.054510   -34.951792
# std       0.911469     1.009927     1.095094     0.002388     0.002310
# min       1.000000     0.000000     0.000000    -8.059550   -34.959850
# 25%       5.000000     3.000000     2.000000    -8.055784   -34.951728
# 50%       5.000000     3.000000     2.000000    -8.055494   -34.951597
# 75%       5.000000     3.000000     3.000000    -8.055310   -34.951331
# max       8.000000     7.000000     7.000000    -8.046420   -34.945110
#
# Estatísticas de df_submit:
#           ponto_id  lat_pred  lon_pred
# count  2904.000000    2904.0    2904.0
# mean   4799.106405      -8.0     -34.0
# std    2814.236124       0.0       0.0
# min       0.000000      -8.0     -34.0
# 25%    2361.000000      -8.0     -34.0
# 50%    4765.500000      -8.0     -34.0
# 75%    7210.250000      -8.0     -34.0
# max    9678.000000      -8.0     -34.0
#
# Estatísticas de df_meds_test:
#           ponto_id     rssi_1_1     rssi_1_2     rssi_1_3     rssi_2_1  \
# count  2904.000000  2904.000000  2904.000000  2904.000000  2904.000000
# mean   4799.106405  -100.991875  -105.885008  -100.685644  -103.411642
# std    2814.236124     9.933416    10.417400     9.978536    13.990015
# min       0.000000  -115.000000  -115.000000  -115.000000  -115.000000
# 25%    2361.000000  -107.650000  -115.000000  -107.148571  -115.000000
# 50%    4765.500000  -103.040000  -110.425000   -99.750000  -108.430000
# 75%    7210.250000   -93.675357   -97.350000   -93.592857   -96.550000
# max    9678.000000   -65.330000   -66.320000   -65.140000   -41.150000
#
#           rssi_2_2     rssi_2_3     rssi_3_1     rssi_3_2     rssi_3_3  \
# count  2904.000000  2904.000000  2904.000000  2904.000000  2904.000000
# mean    -97.397221   -97.361075   -93.790210   -93.232673  -107.604530
# std       9.208718    10.256866     7.553796     8.225281    10.960141
# min    -115.000000  -115.000000  -113.300000  -114.420000  -115.000000
# 25%    -103.315000  -102.440000   -99.380000   -98.787500  -115.000000
# 50%     -97.200000   -95.615714   -95.140000   -95.518000  -115.000000
# 75%     -91.935000   -92.347679   -89.777917   -89.132857   -97.600000
# max     -55.550000   -58.860000   -52.690000   -56.620000   -50.100000
#
#            delay_1      delay_2      delay_3
# count  2904.000000  2904.000000  2904.000000
# mean      4.676653     3.121901     2.535124
# std       0.928623     1.002726     1.134803
# min       1.000000     0.000000     0.000000
# 25%       5.000000     3.000000     2.000000
# 50%       5.000000     3.000000     2.000000
# 75%       5.000000     3.000000     3.000000
# max       7.000000     7.000000     7.000000

# %%
for name, dataset in datasets.items():
    print(f"\nEstatísticas do dataset: {name}\n")

    # Criar um dicionário para armazenar as estatísticas de cada coluna
    stats = {}

    for column in dataset.select_dtypes(include=[np.number]).columns:
        col_data = dataset[column].dropna()
        stats[column] = {
            "Média": col_data.mean(),
            "Mediana": col_data.median(),
            "Moda": mode(col_data, keepdims=True).mode[0] if not col_data.empty else None,
            "Desvio Padrão": col_data.std(),
            "Mínimo": col_data.min(),
            "Máximo": col_data.max(),
            "1º Quartil (Q1)": col_data.quantile(0.25),
            "2º Quartil (Mediana)": col_data.quantile(0.50),
            "3º Quartil (Q3)": col_data.quantile(0.75),
        }

    # Criar DataFrame com as estatísticas
    stats_df = pd.DataFrame(stats)

    # Exibir tabela
    print(stats_df, "\n")
# Out:
# Estatísticas do dataset: df_bts
#
#                          grupo       lat        lon         cch     azimuth
# Média                 2.000000 -8.050543 -34.951524  873.000000  120.000000
# Mediana               2.000000 -8.052890 -34.952000  873.000000  120.000000
# Moda                  1.000000 -8.055320 -34.957900  865.000000    0.000000
# Desvio Padrão         0.866025  0.005445   0.005739    4.609772  103.923048
# Mínimo                1.000000 -8.055320 -34.957900  865.000000    0.000000
# Máximo                3.000000 -8.043420 -34.944672  881.000000  240.000000
# 1º Quartil (Q1)       1.000000 -8.055320 -34.957900  871.000000    0.000000
# 2º Quartil (Mediana)  2.000000 -8.052890 -34.952000  873.000000  120.000000
# 3º Quartil (Q3)       3.000000 -8.043420 -34.944672  875.000000  240.000000
#
#
# Estatísticas do dataset: df_meds_train
#
#                          ponto_id    rssi_1_1    rssi_1_2    rssi_1_3  \
# Média                 4856.099779 -100.789923 -105.688802 -100.545198
# Mediana               4875.000000 -103.040000 -110.425000  -99.750000
# Moda                     1.000000 -115.000000 -115.000000 -115.000000
# Desvio Padrão         2785.645694   10.025728   10.397924    9.968138
# Mínimo                   1.000000 -115.000000 -115.000000 -115.000000
# Máximo                9676.000000  -61.380000  -64.820000  -60.640000
# 1º Quartil (Q1)       2434.500000 -107.650000 -115.000000 -107.148571
# 2º Quartil (Mediana)  4875.000000 -103.040000 -110.425000  -99.750000
# 3º Quartil (Q3)       7272.500000  -93.455000  -97.350000  -93.340000
#
#                         rssi_2_1    rssi_2_2    rssi_2_3    rssi_3_1  \
# Média                -103.524786  -97.210290  -97.193499  -93.644749
# Mediana              -108.430000  -97.170000  -95.615714  -94.785000
# Moda                 -115.000000 -105.835000 -115.000000 -100.030000
# Desvio Padrão          13.367328    8.853480    9.992950    7.688089
# Mínimo               -115.000000 -115.000000 -115.000000 -113.140000
# Máximo                -36.960000  -59.170000  -56.980000  -56.060000
# 1º Quartil (Q1)      -115.000000 -102.202857 -101.652857  -99.480000
# 2º Quartil (Mediana) -108.430000  -97.170000  -95.615714  -94.785000
# 3º Quartil (Q3)       -96.817917  -92.080000  -91.951429  -89.375000
#
#                         rssi_3_2    rssi_3_3   delay_1   delay_2   delay_3  \
# Média                 -93.353728 -107.478361  4.679410  3.159262  2.504945
# Mediana               -95.688000 -115.000000  5.000000  3.000000  2.000000
# Moda                  -78.261429 -115.000000  5.000000  3.000000  2.000000
# Desvio Padrão           8.110877   11.003407  0.911469  1.009927  1.095094
# Mínimo               -115.630000 -115.000000  1.000000  0.000000  0.000000
# Máximo                -55.870000  -52.540000  8.000000  7.000000  7.000000
# 1º Quartil (Q1)       -99.005000 -115.000000  5.000000  3.000000  2.000000
# 2º Quartil (Mediana)  -95.688000 -115.000000  5.000000  3.000000  2.000000
# 3º Quartil (Q3)       -89.610500  -97.600000  5.000000  3.000000  3.000000
#
#                            lat        lon
# Média                -8.054510 -34.951792
# Mediana              -8.055494 -34.951597
# Moda                 -8.055380 -34.951736
# Desvio Padrão         0.002388   0.002310
# Mínimo               -8.059550 -34.959850
# Máximo               -8.046420 -34.945110
# 1º Quartil (Q1)      -8.055784 -34.951728
# 2º Quartil (Mediana) -8.055494 -34.951597
# 3º Quartil (Q3)      -8.055310 -34.951331
#
#
# Estatísticas do dataset: df_submit
#
#                          ponto_id  lat_pred  lon_pred
# Média                 4799.106405      -8.0     -34.0
# Mediana               4765.500000      -8.0     -34.0
# Moda                     0.000000      -8.0     -34.0
# Desvio Padrão         2814.236124       0.0       0.0
# Mínimo                   0.000000      -8.0     -34.0
# Máximo                9678.000000      -8.0     -34.0
# 1º Quartil (Q1)       2361.000000      -8.0     -34.0
# 2º Quartil (Mediana)  4765.500000      -8.0     -34.0
# 3º Quartil (Q3)       7210.250000      -8.0     -34.0
#
#
# Estatísticas do dataset: df_meds_test
#
#                          ponto_id    rssi_1_1    rssi_1_2    rssi_1_3  \
# Média                 4799.106405 -100.991875 -105.885008 -100.685644
# Mediana               4765.500000 -103.040000 -110.425000  -99.750000
# Moda                     0.000000 -115.000000 -115.000000 -115.000000
# Desvio Padrão         2814.236124    9.933416   10.417400    9.978536
# Mínimo                   0.000000 -115.000000 -115.000000 -115.000000
# Máximo                9678.000000  -65.330000  -66.320000  -65.140000
# 1º Quartil (Q1)       2361.000000 -107.650000 -115.000000 -107.148571
# 2º Quartil (Mediana)  4765.500000 -103.040000 -110.425000  -99.750000
# 3º Quartil (Q3)       7210.250000  -93.675357  -97.350000  -93.592857
#
#                         rssi_2_1    rssi_2_2    rssi_2_3    rssi_3_1  \
# Média                -103.411642  -97.397221  -97.361075  -93.790210
# Mediana              -108.430000  -97.200000  -95.615714  -95.140000
# Moda                 -115.000000 -115.000000 -115.000000 -100.030000
# Desvio Padrão          13.990015    9.208718   10.256866    7.553796
# Mínimo               -115.000000 -115.000000 -115.000000 -113.300000
# Máximo                -41.150000  -55.550000  -58.860000  -52.690000
# 1º Quartil (Q1)      -115.000000 -103.315000 -102.440000  -99.380000
# 2º Quartil (Mediana) -108.430000  -97.200000  -95.615714  -95.140000
# 3º Quartil (Q3)       -96.550000  -91.935000  -92.347679  -89.777917
#
#                         rssi_3_2    rssi_3_3   delay_1   delay_2   delay_3
# Média                 -93.232673 -107.604530  4.676653  3.121901  2.535124
# Mediana               -95.518000 -115.000000  5.000000  3.000000  2.000000
# Moda                  -78.261429 -115.000000  5.000000  3.000000  2.000000
# Desvio Padrão           8.225281   10.960141  0.928623  1.002726  1.134803
# Mínimo               -114.420000 -115.000000  1.000000  0.000000  0.000000
# Máximo                -56.620000  -50.100000  7.000000  7.000000  7.000000
# 1º Quartil (Q1)       -98.787500 -115.000000  5.000000  3.000000  2.000000
# 2º Quartil (Mediana)  -95.518000 -115.000000  5.000000  3.000000  2.000000
# 3º Quartil (Q3)       -89.132857  -97.600000  5.000000  3.000000  3.000000

# %%
for name, df in datasets.items():
    plt.figure(figsize=(15, 6))
    for i, column in enumerate(df.columns[1:], 1):  # Ignorar a primeira coluna 'ponto_id'
        plt.subplot(3, 5, i)
        sns.histplot(df[column], bins=20, kde=True)
        plt.title(column)
    plt.suptitle(f"Histogramas para {name}")
    plt.tight_layout()
    plt.show()

# %%
datasets_com_outliers = {"df_meds_train": df_meds_train, "df_meds_test": df_meds_test}

# %%
for name, df in datasets_com_outliers.items():
    # Ajuste o número de colunas para os gráficos lado a lado
    n_columns = 5  # Quantidade de colunas (ajuste conforme necessário)
    n_rows = (len(df.columns) - 1) // n_columns + 1  # Calcula quantas linhas são necessárias

    # Criar figura com tamanho ajustado para múltiplos gráficos
    plt.figure(figsize=(n_columns * 3, n_rows * 3))  # Ajuste o tamanho global dos gráficos

    # Para cada coluna do dataset (exceto a primeira coluna, que é o índice)
    for i, column in enumerate(df.columns[1:], 1):  # Ignora a primeira coluna 'ponto_id'
        # Verifica se a coluna é numérica ou booleana
        if pd.api.types.is_numeric_dtype(df[column]) or pd.api.types.is_bool_dtype(df[column]):
            # Se for booleana, converte para 1 (True) e 0 (False)
            if pd.api.types.is_bool_dtype(df[column]):
                df[column] = df[column].astype(int)

            plt.subplot(n_rows, n_columns, i)  # Organiza os subgráficos

            # Calcular Q1, Q3 e IQR
            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1

            # Definir limites para outliers
            limite_inferior = Q1 - 1.5 * IQR
            limite_superior = Q3 + 1.5 * IQR

            # Exibir os limites para verificar
            print(f"Outliers para {name} - {column}: Limite Inferior: {limite_inferior}, Limite Superior: {limite_superior}")

            # Plotando o boxplot
            sns.boxplot(x=df[column], color="skyblue", width=0.5)

            # Adicionar título e rótulos com fontes menores
            plt.title(f'Boxplot para {column}', fontsize=8)
            plt.xlabel('', fontsize=6)  # Remove o rótulo do eixo X
            plt.ylabel('', fontsize=6)  # Remove o rótulo do eixo Y
            plt.grid(axis='y', linestyle='--', alpha=0.7)  # Adiciona grid no eixo Y
        else:
            print(f"Coluna {column} em {name} não é numérica nem booleana e foi ignorada.")

    # Adicionar título geral para o dataset
    plt.suptitle(f"Boxplots para {name} - Identificação de Outliers", fontsize=12)
    plt.tight_layout()  # Ajusta o layout para evitar sobreposição
    plt.show()
# Out:
# Outliers para df_meds_train - rssi_1_1: Limite Inferior: -128.94250000000002, Limite Superior: -72.1625
# Outliers para df_meds_train - rssi_1_2: Limite Inferior: -141.47500000000002, Limite Superior: -70.87499999999999
# Outliers para df_meds_train - rssi_1_3: Limite Inferior: -127.8614285714275, Limite Superior: -72.6271428571435
# Outliers para df_meds_train - rssi_2_1: Limite Inferior: -142.273125, Limite Superior: -69.54479166666665
# Outliers para df_meds_train - rssi_2_2: Limite Inferior: -117.38714285714249, Limite Superior: -76.89571428571449
# Outliers para df_meds_train - rssi_2_3: Limite Inferior: -116.20499999999964, Limite Superior: -77.39928571428595
# Outliers para df_meds_train - rssi_3_1: Limite Inferior: -114.63750000000002, Limite Superior: -74.2175
# Outliers para df_meds_train - rssi_3_2: Limite Inferior: -113.09674999999999, Limite Superior: -75.51875000000001
# Outliers para df_meds_train - rssi_3_3: Limite Inferior: -141.10000000000002, Limite Superior: -71.49999999999999
# Outliers para df_meds_train - delay_1: Limite Inferior: 5.0, Limite Superior: 5.0
# Outliers para df_meds_train - delay_2: Limite Inferior: 3.0, Limite Superior: 3.0
# Outliers para df_meds_train - delay_3: Limite Inferior: 0.5, Limite Superior: 4.5
# Outliers para df_meds_train - lat: Limite Inferior: -8.056494999999998, Limite Superior: -8.054599000000003
# Outliers para df_meds_train - lon: Limite Inferior: -34.952323500000006, Limite Superior: -34.95073550000001
# Outliers para df_meds_train - indoor: Limite Inferior: -1.5, Limite Superior: 2.5
# Outliers para df_meds_test - rssi_1_1: Limite Inferior: -128.6119642857143, Limite Superior: -72.71339285714288
# Outliers para df_meds_test - rssi_1_2: Limite Inferior: -141.47500000000002, Limite Superior: -70.87499999999999
# Outliers para df_meds_test - rssi_1_3: Limite Inferior: -127.48214285714175, Limite Superior: -73.25928571428642
# Outliers para df_meds_test - rssi_2_1: Limite Inferior: -142.675, Limite Superior: -68.875
# Outliers para df_meds_test - rssi_2_2: Limite Inferior: -120.38499999999999, Limite Superior: -74.86500000000001
# Outliers para df_meds_test - rssi_2_3: Limite Inferior: -117.57848214285715, Limite Superior: -77.2091964285714
# Outliers para df_meds_test - rssi_3_1: Limite Inferior: -113.78312499999998, Limite Superior: -75.37479166666668
# Outliers para df_meds_test - rssi_3_2: Limite Inferior: -113.26946428571435, Limite Superior: -74.65089285714274
# Outliers para df_meds_test - rssi_3_3: Limite Inferior: -141.10000000000002, Limite Superior: -71.49999999999999
# Outliers para df_meds_test - delay_1: Limite Inferior: 5.0, Limite Superior: 5.0
# Outliers para df_meds_test - delay_2: Limite Inferior: 3.0, Limite Superior: 3.0
# Outliers para df_meds_test - delay_3: Limite Inferior: 0.5, Limite Superior: 4.5

# %%
outliers_report = {}

for name, df in datasets_com_outliers.items():
    if name == 'mds train':
        df = df.drop(columns=['indoor'])  # Remove a coluna 'indoor' para o dataset 'mds train'

    df = df.drop(index=0)  # Ignora a primeira linha do dataset

    outliers_report[name] = {}
    numeric_columns = df.select_dtypes(include=[np.number]).columns  # Seleciona apenas colunas numéricas
    for column in numeric_columns:
      Q1 = df[column].quantile(0.25)
      Q3 = df[column].quantile(0.75)
      IQR = Q3 - Q1

      # Definir os limites inferior e superior para outliers
      limite_inferior = Q1 - 1.5 * IQR
      limite_superior = Q3 + 1.5 * IQR

      # Detectar os outliers
      outliers = df[(df[column] < limite_inferior) | (df[column] > limite_superior)]

      if not outliers.empty:
          outliers_report[name][column] = len(outliers)  # Armazena a quantidade de outliers por coluna

# Exibir os resultados
for dataset, columns in outliers_report.items():
    print(f"\nOutliers detectados no dataset {dataset}:")
    if columns:
        for col, count in columns.items():
            print(f"- {col}: {count} outliers detectados")
    else:
        print("Nenhum outlier detectado.")
# Out:
# Outliers detectados no dataset df_meds_train:
# - rssi_1_1: 37 outliers detectados
# - rssi_1_2: 7 outliers detectados
# - rssi_1_3: 35 outliers detectados
# - rssi_2_1: 218 outliers detectados
# - rssi_2_2: 164 outliers detectados
# - rssi_2_3: 131 outliers detectados
# - rssi_3_1: 142 outliers detectados
# - rssi_3_2: 194 outliers detectados
# - rssi_3_3: 105 outliers detectados
# - delay_1: 1573 outliers detectados
# - delay_2: 1751 outliers detectados
# - delay_3: 651 outliers detectados
# - lat: 1676 outliers detectados
# - lon: 2019 outliers detectados
#
# Outliers detectados no dataset df_meds_test:
# - rssi_1_1: 7 outliers detectados
# - rssi_1_2: 1 outliers detectados
# - rssi_1_3: 22 outliers detectados
# - rssi_2_1: 124 outliers detectados
# - rssi_2_2: 40 outliers detectados
# - rssi_2_3: 55 outliers detectados
# - rssi_3_1: 59 outliers detectados
# - rssi_3_2: 84 outliers detectados
# - rssi_3_3: 41 outliers detectados
# - delay_1: 701 outliers detectados
# - delay_2: 743 outliers detectados
# - delay_3: 301 outliers detectados

# %%
def remove_outliers_iqr(df):
    numeric_columns = df.select_dtypes(include=[np.number]).columns  # Seleciona colunas numéricas
    df_clean = df.copy()  # Criar uma cópia do dataframe original

    for column in numeric_columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Filtrar os dados, removendo os outliers
        df_clean = df_clean[(df_clean[column] >= lower_bound) & (df_clean[column] <= upper_bound)]

    return df_clean

# %%
df_meds_train_clean = remove_outliers_iqr(df_meds_train)
df_meds_test_clean = remove_outliers_iqr(df_meds_test)

# %%
print(f"Registros antes da limpeza (df_meds_train): {len(df_meds_train)}")
print(f"Registros após a limpeza (df_meds_train): {len(df_meds_train_clean)}")
print(f"Registros removidos: {len(df_meds_train) - len(df_meds_train_clean)}\n")

print(f"Registros antes da limpeza (df_meds_test): {len(df_meds_test)}")
print(f"Registros após a limpeza (df_meds_test): {len(df_meds_test_clean)}")
print(f"Registros removidos: {len(df_meds_test) - len(df_meds_test_clean)}")
# Out:
# Registros antes da limpeza (df_meds_train): 6775
# Registros após a limpeza (df_meds_train): 4653
# Registros removidos: 2122
#
# Registros antes da limpeza (df_meds_test): 2904
# Registros após a limpeza (df_meds_test): 2014
# Registros removidos: 890

# %%
# Salvar os datasets limpos caso queira utilizá-los depois - NÃO ESTA SALVANDO...
df_meds_train_clean.to_csv("df_meds_train_clean.csv", index=False)
df_meds_test_clean.to_csv("df_meds_test_clean.csv", index=False)
